# %%
import json
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

f = open('final-results.json', )
data = json.load(f)
f.close()


configs = []
for x in data['configs']:
    configs.append({
        'phenotype': x['general']['phenotype'],
        'fitness_function': x['evolution']['fitness_function'],
        'survival_criterion': x['evolution']['survival_selection_criterion'],
        'reproduction_criterion': x['evolution']['reproduction_selection_criterion'],
        'mutation_rate': x['evolution']['mutation_rate'],
        'survival_rate': x['evolution']['survival_rate'],
        'max': x['stats']['time_steps'],
        'mean': np.mean(x['stats']['time_step_history']),
        'median': np.median(x['stats']['time_step_history']),
        'step_history': x['stats']['time_step_history'],
        'best_nn': x['stats']['best_individual'],
        'best_generation': x['stats']['best_generation'],

    })


df = pd.DataFrame(configs)
df = df[df.phenotype == 'nn']
df = df.sample(40)
df = pd.concat([df.drop(['best_nn'], axis=1), df['best_nn'].apply(pd.Series)], axis=1)
df['successful'] = df['max'] > 15000
successful = df[df['successful'] == True]

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>phenotype</th>
#       <th>fitness_function</th>
#       <th>survival_criterion</th>
#       <th>reproduction_criterion</th>
#       <th>mutation_rate</th>
#       <th>survival_rate</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>step_history</th>
#       <th>best_generation</th>
#       <th>hidden_layers</th>
#       <th>weights</th>
#       <th>successful</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>134</th>
#       <td>nn</td>
#       <td>position_and_angle_based</td>
#       <td>uniform</td>
#       <td>uniform</td>
#       <td>0.010</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>25506.525</td>
#       <td>29999.0</td>
#       <td>[29999.0, 1490.0, 414.0, 29999.0, 29999.0, 299...</td>
#       <td>1</td>
#       <td>[1, 6, 4]</td>
#       <td>[0.3103460249092126, 0.13001987548809357, 0.79...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>nn</td>
#       <td>angle_and_time_based</td>
#       <td>tournament</td>
#       <td>rank_proportional</td>
#       <td>0.003</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>29999.000</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[5, 1]</td>
#       <td>[0.26430021711193286, 0.6913559477911424, 0.05...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>163</th>
#       <td>nn</td>
#       <td>position_based</td>
#       <td>elitist</td>
#       <td>fitness_proportional</td>
#       <td>0.010</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>28515.350</td>
#       <td>29999.0</td>
#       <td>[303.0, 349.0, 29999.0, 29999.0, 29999.0, 2999...</td>
#       <td>3</td>
#       <td>[1, 5, 3]</td>
#       <td>[0.2728385161402912, 0.8927644310094226, 0.783...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>nn</td>
#       <td>position_and_angle_based</td>
#       <td>rank_proportional</td>
#       <td>tournament</td>
#       <td>0.010</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>29999.000</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[5, 1]</td>
#       <td>[0.430590169872225, 0.8285320868673874, 0.2076...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th
</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>nn</td>
#       <td>position_and_angle_based</td>
#       <td>fitness_proportional</td>
#       <td>rank_proportional</td>
#       <td>0.003</td>
#       <td>0.0</td>
#       <td>29999.0</td>
#       <td>22859.025</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 4801.0, 29999.0, 2...</td>
#       <td>1</td>
#       <td>[6]</td>
#       <td>[0.7277067702176072, 0.31786715831614576, 0.67...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>135</th>
#       <td>nn</td>
#       <td>time_based</td>
#       <td>elitist</td>
#       <td>tournament</td>
#       <td>0.010</td>
#       <td>0.0</td>
#       <td>29999.0</td>
#       <td>25562.300</td>
#       <td>29999.0</td>
#       <td>[29999.0, 341.0, 29999.0, 29999.0, 29999.0, 29...</td>
#       <td>1</td>
#       <td>[5, 4]</td>
#       <td>[0.2889281238156296, 0.3467696637161939, 0.869...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>nn</td>
#       <td>angle_based</td>
#       <td>uniform</td>
#       <td>elitist</td>
#       <td>0.001</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>24401.875</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[1]</td>
#       <td>[0.12496194688681161, 0.041840856824579276, 0....</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>159</th>
#       <td>nn</td>
#       <td>position_based</td>
#       <td>rank_proportional</td>
#       <td>fitness_proportional</td>
#       <td>0.001</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>29999.000</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[2, 6, 4, 4]</td>
#       <td>[0.848683646476264, 0.280371838145711, 0.89165...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>161</th>
#       <td>nn</td>
#       <td>total_time_steps</td>
#       <td>rank_proportional</td>
#       <td>elitist</td>
#       <td>0.003</td>
#       <td>0.0</td>
#       <td>29999.0</td>
#       <td>26664.350</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[3, 5, 1, 6]</td>
#       <td>[0.25367455504481173, 0.07137191868762105, 0.6...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>158</th>
#       <td>nn</td>
#       <td>position_and_angle_based</td>

# %%
ax = sns.histplot(data=df, x="mean")
ax.set_xlabel('Mean time steps')
ax.set_ylabel('Count')
plt.savefig('mean_dist_nn.png')

# %%
ax = sns.histplot(data=df, x="best_generation")
ax.set_xlabel('Generation #')
ax.set_ylabel('Count')
plt.savefig('gen_dist_nn.png')

# %%
df['mean'].mean()
# Out:
# 27339.525625

# %%
df['median'].median()
# Out:
# 29999.0

# %%
len(df), len(df[df['max'] > 1000])
# Out:
# (40, 40)

# %%
len(df), len(df[df['max'] > 10000])
# Out:
# (40, 40)

# %%
len(successful)
# Out:
# 40

# %%
len(df), len(df[df['max'] > 20000])
# Out:
# (40, 40)

# %%
len(df), len(df[df['max'] > 25000])
# Out:
# (40, 40)

# %%
maxed_out = df[df['max'] == 29999]
len(maxed_out)
# Out:
# 40

# %%
df.groupby('fitness_function')['max'].max()

# %%
df.groupby('fitness_function')['mean'].mean().sort_values()

# %%
df.groupby('fitness_function')['median'].median()

# %%
successful.groupby('fitness_function')['successful'].count().sort_values(ascending=False)

# %%
successful.fitness_function.value_counts()

# %%
fig = go.Figure()
top_10 = successful.sort_values(by='max', ascending=False).head(10)
for x in range(len(top_10)):
    values = top_10[x:x+1].step_history.values.tolist()

    out = []
    for idx, y in enumerate(values[0]):
        out.append({'value': y})

    data = pd.DataFrame(out)

    fig.add_trace(go.Scatter(y=data['value'],
                             mode='lines',
                             name=x +1 ))
    continue
fig.show()
# Out:
# Unsupported

# %%
df.groupby(['fitness_function', 'survival_criterion', 'reproduction_criterion'])['mean'].max().reset_index().sort_values(by='mean',ascending=False).head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fitness_function</th>
#       <th>survival_criterion</th>
#       <th>reproduction_criterion</th>
#       <th>mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>angle_and_time_based</td>
#       <td>rank_proportional</td>
#       <td>elitist</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>total_time_steps</td>
#       <td>fitness_proportional</td>
#       <td>fitness_proportional</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>time_based</td>
#       <td>fitness_proportional</td>
#       <td>rank_proportional</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>time_based</td>
#       <td>elitist</td>
#       <td>tournament</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>position_based</td>
#       <td>rank_proportional</td>
#       <td>fitness_proportional</td>
#       <td>29999.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby(['fitness_function', 'survival_criterion', 'reproduction_criterion'])['median'].max().reset_index().sort_values(by='median',ascending=False).head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fitness_function</th>
#       <th>survival_criterion</th>
#       <th>reproduction_criterion</th>
#       <th>median</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>angle_and_time_based</td>
#       <td>rank_proportional</td>
#       <td>elitist</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>position_and_angle_based</td>
#       <td>uniform</td>
#       <td>tournament</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>total_time_steps</td>
#       <td>rank_proportional</td>
#       <td>rank_proportional</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>total_time_steps</td>
#       <td>rank_proportional</td>
#       <td>elitist</td>
#       <td>29999.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>total_time_steps</td>
#       <td>fitness_proportional</td>
#       <td>fitness_proportional</td>
#       <td>29999.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>phenotype</th>
#       <th>fitness_function</th>
#       <th>survival_criterion</th>
#       <th>reproduction_criterion</th>
#       <th>mutation_rate</th>
#       <th>survival_rate</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>step_history</th>
#       <th>best_generation</th>
#       <th>hidden_layers</th>
#       <th>weights</th>
#       <th>successful</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>134</th>
#       <td>nn</td>
#       <td>position_and_angle_based</td>
#       <td>uniform</td>
#       <td>uniform</td>
#       <td>0.010</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>25506.525</td>
#       <td>29999.0</td>
#       <td>[29999.0, 1490.0, 414.0, 29999.0, 29999.0, 299...</td>
#       <td>1</td>
#       <td>[1, 6, 4]</td>
#       <td>[0.3103460249092126, 0.13001987548809357, 0.79...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>nn</td>
#       <td>angle_and_time_based</td>
#       <td>tournament</td>
#       <td>rank_proportional</td>
#       <td>0.003</td>
#       <td>0.1</td>
#       <td>29999.0</td>
#       <td>29999.000</td>
#       <td>29999.0</td>
#       <td>[29999.0, 29999.0, 29999.0, 29999.0, 29999.0, ...</td>
#       <td>1</td>
#       <td>[5, 1]</td>
#       <td>[0.26430021711193286, 0.6913559477911424, 0.05...</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th